# %% [markdown]
# # ***Importing Libraries***

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import numpy as np
import cv2
import glob
import yaml
import torchvision
from torch.optim.lr_scheduler import ReduceLROnPlateau
import gc

# %% [markdown]
# # ***Loading Dataset***

# %%
# Load data.yaml and handle potential errors
dataset_path = '/kaggle/input/liver-disease-dataset'
data_yaml_path = os.path.join(dataset_path, 'dataset', 'data.yaml')  # Corrected path
dataset_root = os.path.join(dataset_path, 'dataset')

# Extract information from data.yaml, handling missing keys
train_images_folder = os.path.join(dataset_root, "images", "train")
train_labels_folder = os.path.join(dataset_root, "labels", "train")
val_images_folder = os.path.join(dataset_root, "images", "val")
val_labels_folder = os.path.join(dataset_root, "labels", "val")
test_images_folder = os.path.join(dataset_root, "images", "test")
test_labels_folder = os.path.join(dataset_root, "labels", "test")
data_yaml = os.path.join(dataset_root, "data.yaml")

# Set hyperparameters
batch_size = 4  # Reduced from 8
img_size = 416  # Reduced from 640
gradient_accumulation_steps = 2

# CUDA check
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:512'
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # ***Residue Block***

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential() if in_channels == out_channels and stride == 1 else \
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride)

    def forward(self, x):
        identity = self.shortcut(x)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += identity
        out = self.relu(out)
        return out

# %% [markdown]
# # ***Stable Loss***

# %%
# Update the StableLoss class to handle shape mismatches better
class StableLoss(nn.Module):
    def __init__(self, num_classes):
        super(StableLoss, self).__init__()
        self.num_classes = num_classes
        self.mse = nn.MSELoss(reduction='mean')
        self.bce = nn.BCEWithLogitsLoss(reduction='mean')
        self.entropy = nn.CrossEntropyLoss(reduction='mean')
    
    def forward(self, predictions, targets):
        # Verify shapes match
        if predictions.shape != targets.shape:
            raise ValueError(f"Shape mismatch: predictions {predictions.shape} vs targets {targets.shape}")
        
        # Extract target components
        obj_mask = targets[..., 4] > 0
        noobj_mask = targets[..., 4] == 0
        
        # No object loss
        noobj_loss = self.bce(
            predictions[..., 4][noobj_mask],
            targets[..., 4][noobj_mask]
        )
        
        if obj_mask.sum() > 0:
            # Box coordinates loss
            box_loss = self.mse(
                predictions[..., :4][obj_mask],
                targets[..., :4][obj_mask]
            )
            
            # Objectness loss
            obj_loss = self.bce(
                predictions[..., 4][obj_mask],
                targets[..., 4][obj_mask]
            )
            
            # Class prediction loss
            class_loss = self.entropy(
                predictions[..., 5:][obj_mask],
                targets[..., 5][obj_mask].long()
            )
            
            # Combine losses with weights
            total_loss = (
                box_loss * 1.0 +
                obj_loss * 1.0 +
                noobj_loss * 0.5 +
                class_loss * 1.0
            )
        else:
            total_loss = noobj_loss
        
        return total_loss

# %% [markdown]
# # ***YOLOv5 Class***

# %%
# First, modify the ImprovedYOLOv5 class to explicitly return the grid size
class ImprovedYOLOv5(nn.Module):
    def __init__(self, num_classes):
        super(ImprovedYOLOv5, self).__init__()
        self.num_classes = num_classes

        # Backbone
        self.backbone = nn.Sequential(
            ResidualBlock(3, 32, stride=2), # 208x208
            ResidualBlock(32, 64),
            nn.MaxPool2d(2), # 104x104
            ResidualBlock(64, 128),
            ResidualBlock(128, 256),
            nn.MaxPool2d(2), # 52x52
            ResidualBlock(256, 512),
            ResidualBlock(512, 1024),
        )

        # Neck
        self.neck = nn.Sequential(
            nn.Conv2d(1024, 512, kernel_size=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )

        # Detection head
        self.head = nn.Sequential(
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, (num_classes + 5), kernel_size=1) # 5 = (x,y,w,h,obj)
        )

    def forward(self, x):
        x = self.backbone(x)
        x = self.neck(x)
        x = self.head(x)

        # Reshape output to [batch_size, grid_size*grid_size, num_classes + 5]
        batch_size, channels, height, width = x.shape
        x = x.permute(0, 2, 3, 1).contiguous()
        x = x.view(batch_size, height * width, channels)

        return x, (height, width)  # Return grid dimensions too

# %% [markdown]
# # ***Custom Dataset***

# %%
# Custom Dataset with Improved Error Handling
class ImprovedCustomDataset(Dataset):
    def __init__(self, images_folder, labels_folder, img_size=640, augment=False):
        self.images_folder = images_folder
        self.labels_folder = labels_folder
        self.img_size = img_size
        self.augment = augment

        self.image_paths = sorted(
            glob.glob(os.path.join(images_folder, '*.jpg')) +
            glob.glob(os.path.join(images_folder, '*.jpeg')) +
            glob.glob(os.path.join(images_folder, '*.png'))
        )
        print(f"Found {len(self.image_paths)} images in {images_folder}")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = self._load_image(image_path)
        
        image_filename = os.path.basename(image_path)
        label_filename = os.path.splitext(image_filename)[0] + '.txt'
        label_path = os.path.join(self.labels_folder, label_filename)
        
        label = self._load_label(label_path)
        
        if self.augment:
            image, label = self._augment_data(image, label)
        
        return image, label

    def _load_image(self, image_path):
        try:
            image = cv2.imread(image_path)
            image = cv2.resize(image, (self.img_size, self.img_size))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = image.astype(np.float32) / 255.0
            image = np.transpose(image, (2, 0, 1))
            return torch.tensor(image).float()
        except Exception as e:
            print(f"Error loading image {image_path}: {e}")
            return torch.zeros((3, self.img_size, self.img_size))

    def _load_label(self, label_path):
        try:
            if os.path.exists(label_path) and os.path.getsize(label_path) > 0:
                labels = np.loadtxt(label_path, delimiter=' ', ndmin=2)
                if labels.size > 0:
                    return torch.tensor(labels).float()
            return torch.zeros((0, 5))
        except Exception as e:
            print(f"Warning: Error loading label {label_path}: {str(e)}")
            return torch.zeros((0, 5))

    def _augment_data(self, image, label):
        if np.random.random() < 0.5:
            image = torch.flip(image, [2])
            if label.size(0) > 0:
                label[:, 1] = 1 - label[:, 1]
        return image, label

# %%
# Collate function
def collate_fn(batch):
    images = []
    labels = []
    for img, label in batch:
        if img is not None:
            images.append(img)
            labels.append(label)
    if len(images) > 0:
        images = torch.stack(images, dim=0)
        labels = labels  # Keep labels as a list of tensors
        return images, labels
    else:
        return None, None

# %%
# Prepare targets
def prepare_targets(target_list, device, num_classes, grid_size):
    batch_size = len(target_list)
    grid_height, grid_width = grid_size
    total_grid_cells = grid_height * grid_width
    
    target_tensor = torch.zeros((batch_size, total_grid_cells, num_classes + 5), device=device)

    for batch_index, targets in enumerate(target_list):
        if targets.numel() == 0:
            continue

        for target in targets:
            class_index = int(target[0])
            x_center, y_center, width, height = target[1:5]

            # Scale x,y to grid dimensions
            i = int(x_center * grid_width)
            j = int(y_center * grid_height)
            
            # Bound check to prevent index errors
            i = min(max(i, 0), grid_width - 1)
            j = min(max(j, 0), grid_height - 1)

            one_hot = torch.zeros(num_classes, device=device)
            one_hot[class_index] = 1.0

            x_cell = x_center * grid_width - i
            y_cell = y_center * grid_height - j

            index = j * grid_width + i
            target_tensor[batch_index, index, 0:4] = torch.tensor([x_cell, y_cell, width, height], device=device)
            target_tensor[batch_index, index, 4] = 1.0
            target_tensor[batch_index, index, 5:] = one_hot

    return target_tensor

# %%
import math

def calculate_metrics(predictions, targets, iou_threshold=0.5):
    """
    Calculate object detection metrics.
    
    Args:
        predictions: Model predictions in format [batch_size, grid_cells, 5+num_classes]
        targets: Ground truth targets in same format
        iou_threshold: IoU threshold to consider detection as correct
        
    Returns:
        Dictionary of metrics including accuracy, precision, recall, F1 score
    """
    batch_size = predictions.size(0)
    metrics = {
        'accuracy': 0.0,
        'precision': 0.0,
        'recall': 0.0,
        'f1_score': 0.0
    }
    
    total_tp = 0
    total_fp = 0
    total_fn = 0
    
    # Process each image in batch
    for i in range(batch_size):
        # Apply sigmoid to objectness and softmax to class predictions
        pred_objectness = torch.sigmoid(predictions[i, :, 4])
        pred_classes = torch.softmax(predictions[i, :, 5:], dim=1)
        
        # Get objectness mask from targets (ground truth)
        target_obj_mask = targets[i, :, 4] > 0.5
        
        # If there are no objects in this image, skip
        if not target_obj_mask.any():
            continue
            
        # Count how many grid cells have objects (true positives + false negatives)
        num_gt_objects = target_obj_mask.sum().item()
        
        # Count predictions with objectness > 0.5 (true positives + false positives)
        pred_obj_mask = pred_objectness > 0.5
        num_pred_objects = pred_obj_mask.sum().item()
        
        # Count correct object detections (objectness and position)
        # This is a simplified accuracy measure
        correct_obj = (pred_obj_mask & target_obj_mask).sum().item()
        
        # Calculate metrics for this image
        tp = correct_obj
        fp = num_pred_objects - tp
        fn = num_gt_objects - tp
        
        # Accumulate for batch metrics
        total_tp += tp
        total_fp += fp
        total_fn += fn
        
        # Image accuracy = percentage of grid cells correctly classified
        batch_accuracy = correct_obj / max(1, num_gt_objects)
        metrics['accuracy'] += batch_accuracy
    
    # Calculate batch-level metrics
    metrics['accuracy'] /= batch_size
    
    # Precision = TP / (TP + FP)
    metrics['precision'] = total_tp / max(1, total_tp + total_fp)
    
    # Recall = TP / (TP + FN)
    metrics['recall'] = total_tp / max(1, total_tp + total_fn)
    
    # F1 score = 2 * Precision * Recall / (Precision + Recall)
    if metrics['precision'] + metrics['recall'] > 0:
        metrics['f1_score'] = 2 * metrics['precision'] * metrics['recall'] / (metrics['precision'] + metrics['recall'])
    
    return metrics

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device):
    best_val_loss = float('inf')
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        train_metrics = {'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0}
        optimizer.zero_grad()
        
        # Track batches for gradient accumulation
        valid_batches = 0
        
        for batch_idx, (batch_images, batch_targets) in enumerate(train_loader):
            if batch_images is None:
                continue
            
            try:
                batch_images = batch_images.to(device)
                
                # Get both outputs and grid size
                outputs, grid_size = model(batch_images)
                
                # Use the actual grid size from the model
                prepared_targets = prepare_targets(batch_targets, device, model.num_classes, grid_size)
                
                loss = criterion(outputs, prepared_targets)
                
                # Calculate metrics
                batch_metrics = calculate_metrics(outputs, prepared_targets)
                for key in train_metrics:
                    train_metrics[key] += batch_metrics.get(key, 0.0)
                
                # Normalize loss by gradient accumulation steps
                loss = loss / gradient_accumulation_steps
                loss.backward()
                
                if (batch_idx + 1) % gradient_accumulation_steps == 0:
                    # Gradient clipping to prevent explosion
                    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                    optimizer.step()
                    optimizer.zero_grad()
                
                train_loss += loss.item() * gradient_accumulation_steps
                valid_batches += 1
                
                # Print progress
                if batch_idx % 20 == 0:
                    print(f'Train Epoch: {epoch+1} [{batch_idx}/{len(train_loader)}] Loss: {loss.item():.4f}')
                
                # Clean up GPU memory
                del outputs, loss, batch_images, prepared_targets
                torch.cuda.empty_cache()
            
            except RuntimeError as e:
                if "out of memory" in str(e):
                    print(f"WARNING: out of memory on batch {batch_idx}. Skipping...")
                    if torch.cuda.is_available():
                        torch.cuda.empty_cache()
                    continue
                else:
                    print(f"Error in batch {batch_idx}: {str(e)}")
                    raise e
        
        # Validation phase
        model.eval()
        val_loss = 0.0
        val_metrics = {'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0}
        valid_val_batches = 0
        
        with torch.no_grad():
            for val_images, val_targets in val_loader:
                if val_images is None:
                    continue
                
                try:
                    val_images = val_images.to(device)
                    
                    # Get both outputs and grid size
                    val_outputs, val_grid_size = model(val_images)
                    
                    # Use the actual grid size from the model
                    prepared_val_targets = prepare_targets(val_targets, device, model.num_classes, val_grid_size)
                    
                    val_batch_loss = criterion(val_outputs, prepared_val_targets)
                    val_loss += val_batch_loss.item()
                    
                    # Calculate validation metrics
                    batch_val_metrics = calculate_metrics(val_outputs, prepared_val_targets)
                    for key in val_metrics:
                        val_metrics[key] += batch_val_metrics.get(key, 0.0)
                    
                    valid_val_batches += 1
                    
                    # Clean up GPU memory
                    del val_outputs, val_batch_loss, val_images, prepared_val_targets
                    torch.cuda.empty_cache()
                
                except RuntimeError as e:
                    if "out of memory" in str(e):
                        print("WARNING: out of memory during validation. Skipping batch...")
                        if torch.cuda.is_available():
                            torch.cuda.empty_cache()
                        continue
                    else:
                        print(f"Error in validation: {str(e)}")
                        raise e

        # Calculate epoch metrics
        avg_train_loss = train_loss / max(1, valid_batches)
        avg_val_loss = val_loss / max(1, valid_val_batches)
        
        # Average the metrics
        for key in train_metrics:
            train_metrics[key] /= max(1, valid_batches)
            val_metrics[key] /= max(1, valid_val_batches)
        
        # Print epoch results
        print(f'Epoch {epoch+1}/{num_epochs}')
        print(f'Train Loss: {avg_train_loss:.4f}, Acc: {train_metrics["accuracy"]:.4f}, P: {train_metrics["precision"]:.4f}, R: {train_metrics["recall"]:.4f}, F1: {train_metrics["f1_score"]:.4f}')
        print(f'Val Loss: {avg_val_loss:.4f}, Acc: {val_metrics["accuracy"]:.4f}, P: {val_metrics["precision"]:.4f}, R: {val_metrics["recall"]:.4f}, F1: {val_metrics["f1_score"]:.4f}')
        
        # Update learning rate based on validation loss
        scheduler.step(avg_val_loss)
        
        # Clean up memory
        gc.collect()
        torch.cuda.empty_cache()
        
        # Save best model
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            print(f"Saving best model with val_loss: {best_val_loss:.4f}")
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': best_val_loss,
                'metrics': val_metrics
            }, 'best_liver_disease_model.pth')
        
    return model

# %%
def predict_disease(model, image_path, device, img_size=416, confidence_threshold=0.5):
    """
    Predict liver disease from image.

    Args:
        model: Trained model
        image_path: Path to the liver image
        device: Device to run inference on
        img_size: Input image size
        confidence_threshold: Threshold for detection confidence

    Returns:
        List of detections with disease class, confidence, and bounding box
    """
    # Load and preprocess image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error: Could not load image from {image_path}")
        return []

    original_h, original_w = image.shape[:2]
    image = cv2.resize(image, (img_size, img_size))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = image.astype(np.float32) / 255.0
    image = np.transpose(image, (2, 0, 1))
    image_tensor = torch.tensor(image).float().unsqueeze(0).to(device)

    # Run inference
    model.eval()
    with torch.no_grad():
        predictions, grid_size = model(image_tensor)

    # Convert predictions to boxes
    raw_detections = extract_boxes(predictions[0], confidence_threshold)

    # Convert to output format with class names
    class_names = ['healthy', 'fatty_liver', 'cirrhosis', 'hepatitis']

    detections = []
    for det in raw_detections:
        x1, y1, x2, y2 = det['bbox']
        class_id = det['class_id']
        confidence = det['confidence'] * det['class_prob']  # Combined confidence

        # Convert normalized coordinates to image coordinates
        x1_img = x1 * original_w
        y1_img = y1 * original_h
        x2_img = x2 * original_w
        y2_img = y2 * original_h

        detections.append({
            'disease': class_names[class_id],
            'class_id': class_id,  # Include class_id
            'confidence': confidence,
            'bbox': [x1_img, y1_img, x2_img, y2_img]
        })

    return detections

# %%
def extract_boxes(grid_predictions, confidence_threshold=0.5):
    """
    Convert grid cell predictions to bounding boxes.

    Args:
        grid_predictions: Tensor of shape [grid_cells, 5+num_classes]
        confidence_threshold: Minimum confidence to keep a detection

    Returns:
        List of dictionaries with format:
        {
            'box': [x1, y1, x2, y2],  # normalized 0-1 coordinates
            'confidence': float,       # objectness score
            'class_id': int,           # predicted class ID
            'class_prob': float        # class probability
        }
    """
    grid_cells = grid_predictions.size(0)
    grid_size = int(math.sqrt(grid_cells))
    num_classes = grid_predictions.size(1) - 5

    # Apply sigmoid to objectness
    objectness = torch.sigmoid(grid_predictions[:, 4])
    confident_mask = objectness > confidence_threshold

    if not confident_mask.any():
        return []

    confident_indices = confident_mask.nonzero(as_tuple=True)[0]
    grid_y = torch.div(confident_indices, grid_size, rounding_mode='floor')
    grid_x = confident_indices % grid_size

    confident_preds = grid_predictions[confident_indices]

    x_center = (torch.sigmoid(confident_preds[:, 0]) + grid_x) / grid_size
    y_center = (torch.sigmoid(confident_preds[:, 1]) + grid_y) / grid_size
    w = torch.exp(confident_preds[:, 2])  # Apply exponential to width
    h = torch.exp(confident_preds[:, 3])  # Apply exponential to height

    x1 = torch.clamp(x_center - w/2, 0, 1)
    y1 = torch.clamp(y_center - h/2, 0, 1)
    x2 = torch.clamp(x_center + w/2, 0, 1)
    y2 = torch.clamp(y_center + h/2, 0, 1)

    class_probs = torch.softmax(confident_preds[:, 5:], dim=1)
    class_ids = torch.argmax(class_probs, dim=1)
    max_class_probs = torch.max(class_probs, dim=1)[0]

    detections = []
    for i in range(len(confident_indices)):
        if w[i] * h[i] > 0:
            detections.append({
                'bbox': [x1[i].item(), y1[i].item(), x2[i].item(), y2[i].item()],
                'confidence': objectness[confident_indices[i]].item(),
                'class_id': class_ids[i].item(),
                'class_prob': max_class_probs[i].item()
            })

    return detections

# %%
def visualize_prediction(image_path, detections):
    """
    Visualize disease detection results using precise circular markers
    at the center of detected regions instead of large bounding boxes.
    
    Args:
        image_path: Path to the original image
        detections: List of detection dictionaries
    """
    image = cv2.imread(image_path)
    if image is None:
        print("Error reading the image.")
        return

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Colors for different classes
    colors = {
        'fatty_liver': (255, 223, 0),  # Bright yellow
        'cirrhosis': (255, 0, 85),     # Magenta-red
        'hepatitis': (0, 191, 255)     # Deep sky blue
    }
    
    # Draw detections only if there are any
    if detections:
        for detection in detections:
            # Skip 'healthy' class
            if detection['disease'] == 'healthy' or detection['class_id'] == 0:
                continue
                
            # Get bounding box coordinates
            x1, y1, x2, y2 = [int(coord) for coord in detection['bbox']]
            
            # Calculate center point of the detection
            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2
            
            disease = detection['disease']
            confidence = detection['confidence']
            color = colors.get(disease, (255, 255, 255))
            
            # Draw a crosshair at the center
            line_length = 10
            thickness = 2
            
            # Horizontal line
            cv2.line(image, 
                     (center_x - line_length, center_y), 
                     (center_x + line_length, center_y), 
                     color, thickness)
            
            # Vertical line
            cv2.line(image, 
                     (center_x, center_y - line_length), 
                     (center_x, center_y + line_length), 
                     color, thickness)
            
            # Draw circle around the center
            radius = 20
            cv2.circle(image, (center_x, center_y), radius, color, 2)
            
            # Add arrow pointing to the detection with label
            arrow_length = 40
            text_offset_x = 50
            text_offset_y = 20
            
            # Choose direction for arrow and text (avoid going off-image)
            if center_x < image.shape[1] // 2:  # Left half of image
                # Arrow points right
                arrow_end_x = center_x + arrow_length
                text_x = center_x + text_offset_x
            else:  # Right half of image
                # Arrow points left
                arrow_end_x = center_x - arrow_length
                text_x = center_x - text_offset_x - 150  # Width for text
            
            # Draw arrow
            cv2.arrowedLine(image, 
                           (center_x, center_y), 
                           (arrow_end_x, center_y), 
                           color, 2, tipLength=0.3)
            
            # Add label with confidence
            label = f"{disease}: {confidence:.2f}"
            cv2.putText(image, label, (text_x, center_y + text_offset_y), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.4, color, 2)
            
            # Optional: Mark small dots at specific points within the detection
            # (e.g., points of highest abnormality)
            points_to_highlight = [
                (center_x - 10, center_y - 10),
                (center_x + 8, center_y + 5),
                (center_x - 5, center_y + 12)
            ]
            
            for point in points_to_highlight:
                cv2.circle(image, point, 3, color, -1)  # Small filled circle
    
    # Display the image with annotations
    plt.figure(figsize=(12, 9))
    plt.imshow(image)
    plt.axis('off')
    plt.title('Liver Disease Detection - Specific Areas', fontsize=16)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # ***Training***

# %%
# Instantiate Datasets
train_dataset = ImprovedCustomDataset(train_images_folder, train_labels_folder, img_size=img_size, augment=True)
val_dataset = ImprovedCustomDataset(val_images_folder, val_labels_folder, img_size=img_size, augment=False)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2, collate_fn=collate_fn)

# Model and Optimizer
model = ImprovedYOLOv5(num_classes=4).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
criterion = StableLoss(num_classes=4).to(device)
num_epochs = 10

# Train model
trained_model = train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device)
# Out:
# Found 2782 images in /kaggle/input/liver-disease-dataset/dataset/images/train
# Found 794 images in /kaggle/input/liver-disease-dataset/dataset/images/val
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Train
:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('best_liver_disease_model.pth')
# Detected healthy with 0.85 confidence
# Location: [66.32081073522568, 0.0, 299.0, 172.44314712285995]
# Detected healthy with 0.73 confidence
# Location: [72.64563882350922, 0.0, 299.0, 177.30437862873077]
# Detected healthy with 0.56 confidence
# Location: [0.0, 0.0, 295.8562364578247, 181.7227743268013]
# Detected healthy with 0.82 confidence
# Location: [0.0, 0.0, 299.0, 180.89096015691757]
# Detected healthy with 0.69 confidence
# Location: [0.0, 0.0, 299.0, 182.24495273828506]
# Detected healthy with 0.56 confidence
# Location: [94.91262727975845, 0.0, 299.0, 183.2686184644699]
# Detected healthy with 0.85 confidence
# Location: [103.18109965324402, 0.0, 299.0, 178.52896720170975]
# Detected healthy with 0.76 confidence
# Location: [108.66972941160202, 0.0, 299.0, 179.2650070786476]
# Detected healthy with 0.90 confidence
# Location: [0.0, 0.0, 205.25714147090912, 188.2078559398651]
# Detected healthy with 0.96 confidence
# Location: [0.0, 0.0, 198.12792694568634, 202.78679203987122]
# Detected healthy with 0.99 confidence
# Location: [0.0, 0.0, 202.9118653535843, 195.88754987716675]
# Detected healthy with 0.53 confidence
# Location: [0.0, 0.0, 217.27783107757568, 208.64486747980118]
# Detected healthy with 0.95 confidence
# Location: [0.0, 0.0, 196.90918391942978, 205.92877340316772]
# Detected healthy with 0.95 confidence
# Location: [0.0, 0.0, 217.97797787189484, 207.19936001300812]
# Detected healthy with 0.88 confidence
# Location: [30.886621356010437, 0.0, 299.0, 201.55691039562225]
# Detected healthy with 0.67 confidence
# Location: [39.377028465270996, 0.0, 299.0, 200.42219710350037]
# Detected healthy with 0.83 confidence
# Location: [0.0, 0.0, 233.53814601898193, 210.82623660564423]
# Detected healthy with 0.88 confidence
# Location: [0.0, 0.0, 235.89192312955856, 205.72542679309845]
# Detected healthy with 0.85 confidence
# Location: [27.566047847270966, 0.0, 299.0, 212.8812314271927]
# Detected healthy with 0.77 confidence
# Location: [26.733003973960876, 0.0, 299.0, 217.36879348754883]
# Detected healthy with 0.89 confidence
# Location: [0.0, 0.0, 236.56505209207535, 216.983628988266]
# Detected healthy with 0.72 confidence
# Location: [0.0, 0.0, 248.32652378082275, 225.06071317195892]
# Detected healthy with 0.53 confidence
# Location: [119.38226407766342, 0.0, 299.0, 219.22858625650406]
# Detected healthy with 0.92 confidence
# Location: [118.45328551530838, 0.0, 299.0, 228.9997027516365]
# Detected healthy with 0.71 confidence
# Location: [124.96998298168182, 0.0, 299.0, 230.8973846435547]
# Detected healthy with 0.90 confidence
# Location: [0.0, 0.0, 299.0, 229.11586517095566]
# Detected healthy with 0.87 confidence
# Location: [2.066365122795105, 0.0, 299.0, 227.68694978952408]
# Detected healthy with 0.81 confidence
# Location: [81.10959839820862, 0.0, 299.0, 228.9538472890854]
# Detected healthy with 0.79 confidence
# Location: [88.35832583904266, 0.0, 299.0, 230.77708756923676]
# Detected healthy with 0.94 confidence
# Location: [118.27627950906754, 0.0, 299.0, 232.37056934833527]
# Detected healthy with 0.74 confidence
# Location: [123.29976058006287, 0.0, 299.0, 237.9538328051567]
# Detected healthy with 0.51 confidence
# Location: [0.0, 0.0, 299.0, 243.2343218922615]
# Detected healthy with 0.98 confidence
# Location: [0.0, 0.0, 299.0, 238.36799335479736]
# Detected healthy with 0.99 confidence
# Location: [0.0, 0.0, 299.0, 235.31323182582855]
# Detected healthy with 0.62 confidence
# Location: [3.8499162793159485, 0.0, 299.0, 236.79997891187668]
# Detected healthy with 0.93 confidence
# Location: [79.57467901706696, 0.0, 299.0, 235.80591517686844]
# Detected healthy with 0.86 confidence
# Location: [78.32305479049683, 0.0, 299.0, 240.70259422063828]
# Detected healthy with 0.78 confidence
# Location: [119.95810389518738, 0.0, 299.0, 240.36786538362503]
# Detected healthy with 0.49 confidence
# Location: [117.7155169248581, 0.0, 299.0, 245.23681372404099]
# Detected healthy with 0.74 confidence
# Location: [0.0, 0.0, 299.0, 246.07103383541107]
# Detected healthy with 0.72 confidence
# Location: [0.0, 0.0, 299.0, 251.45574474334717]
# Detected healthy with 0.70 confidence
# Location: [0.0, 0.0, 271.1087401509285, 241.49051332473755]
# Detected healthy with 0.85 confidence
# Location: [0.0, 0.0, 281.6254668235779, 241.35316079854965]
# Detected healthy with 0.81 confidence
# Location: [0.0, 0.0, 280.1256029009819, 237.86098128557205]
# Detected healthy with 0.57 confidence
# Location: [0.0, 0.0, 204.0597311258316, 273.2720379829407]
# Detected healthy with 0.68 confidence
# Location: [0.0, 0.0, 203.71049535274506, 273.7375431060791]
# Detected healthy with 0.60 confidence
# Location: [0.0, 0.0, 202.38696020841599, 275.71911215782166]
# Detected healthy with 0.93 confidence
# Location: [0.0, 0.0, 264.2581692934036, 270.72972416877747]
# Detected healthy with 0.82 confidence
# Location: [0.0, 0.0, 265.89431643486023, 272.72943580150604]
# Detected healthy with 0.84 confidence
# Location: [0.0, 0.0, 299.0, 275.018840610981]
# Detected healthy with 0.91 confidence
# Location: [0.0, 0.0, 299.0, 274.12750166654587]
# Detected healthy with 0.74 confidence
# Location: [0.0, 0.0, 299.0, 275.82657754421234]
# Detected healthy with 0.78 confidence
# Location: [57.18074595928192, 0.0, 299.0, 277.51517421007156]
# Detected healthy with 0.76 confidence
# Location: [68.41642141342163, 0.0, 299.0, 276.11867666244507]
# Detected fatty_liver with 0.36 confidence
# Location: [0.0, 0.0, 266.4866592288017, 284.6309867501259]
# Detected healthy with 0.81 confidence
# Location: [0.0, 0.0, 255.8431839942932, 285.84459710121155]
# Detected healthy with 0.98 confidence
# Location: [0.0, 0.0, 267.5221764445305, 283.7246596813202]
# Detected healthy with 0.94 confidence
# Location: [0.0, 0.0, 275.2484030723572, 281.3902904987335]
# Detected healthy with 0.92 confidence
# Location: [0.0, 0.0, 299.0, 284.0197528600693]
# Detected healthy with 0.97 confidence
# Location: [0.0, 0.0, 299.0, 284.2206757068634]
# Detected healthy with 0.96 confidence
# Location: [0.0, 0.0, 299.0, 283.7010636329651]
# Detected healthy with 0.72 confidence
# Location: [0.0, 0.0, 299.0, 280.98213589191437]
# Detected healthy with 0.97 confidence
# Location: [55.230008602142334, 0.0, 299.0, 284.0839112997055]
# Detected healthy with 0.97 confidence
# Location: [66.45246028900146, 0.0, 299.0, 283.1129446029663]
# Detected healthy with 0.62 confidence
# Location: [0.0, 0.0, 285.1389968395233, 299.0]
# Detected healthy with 0.78 confidence
# Location: [0.0, 0.0, 299.0, 290.09708976745605]
# Detected healthy with 0.97 confidence
# Location: [0.0, 0.0, 299.0, 287.3245719075203]
# Detected healthy with 0.97 confidence
# Location: [0.0, 0.0, 299.0, 289.4955865740776]
# Detected healthy with 0.88 confidence
# Location: [0.0, 0.0, 299.0, 290.05282044410706]
# Detected healthy with 0.92 confidence
# Location: [59.39918440580368, 0.0, 299.0, 291.63724875450134]
# Detected healthy with 0.89 confidence
# Location: [58.291791915893555, 0.0, 299.0, 294.7598400115967]
# Detected healthy with 0.76 confidence
# Location: [0.0, 0.0, 299.0, 291.4880625605583]
# Detected healthy with 0.91 confidence
# Location: [0.0, 0.0, 299.0, 288.8795051574707]
# Detected healthy with 0.85 confidence
# Location: [0.0, 0.0, 299.0, 288.0285682082176]
# Detected healthy with 0.50 confidence
# Location: [0.0, 0.0, 299.0, 295.21880453824997]
# Detected healthy with 0.75 confidence
# Location: [104.34709018468857, 0.0, 299.0, 292.6285144686699]
# Detected healthy with 0.98 confidence
# Location: [106.3688651919365, 0.0, 299.0, 288.6240476369858]
# Detected healthy with 0.64 confidence
# Location: [0.0, 0.0, 220.1130103468895, 299.0]
# Detected healthy with 0.55 confidence
# Location: [0.0, 0.0, 226.53033351898193, 297.6614410877228]
# Detected healthy with 0.83 confidence
# Location: [92.18829953670502, 0.0, 299.0, 299.0]
# Detected healthy with 0.55 confidence
# Location: [0.0, 0.0, 224.3185960650444, 299.0]
# Detected healthy with 0.82 confidence
# Location: [0.0, 0.0, 221.15936321020126, 299.0]
# Detected healthy with 0.85 confidence
# Location: [0.0, 0.0, 225.38553309440613, 299.0]
# Detected healthy with 0.62 confidence
# Location: [0.0, 0.0, 236.95615124702454, 299.0]
# Detected healthy with 0.63 confidence
# Location: [10.953057527542114, 0.0, 299.0, 299.0]
# Detected healthy with 0.65 confidence
# Location: [17.562499582767487, 0.0, 299.0, 299.0]
# Detected healthy with 0.55 confidence
# Location: [61.18216526508331, 0.0, 299.0, 299.0]
# Detected healthy with 0.70 confidence
# Location: [0.0, 0.0, 190.135888338089, 299.0]
# Detected healthy with 0.94 confidence
# Location: [0.0, 0.0, 198.45586568117142, 299.0]
# Detected healthy with 0.63 confidence
# Location: [0.0, 0.0, 211.67767256498337, 299.0]
# Detected healthy with 0.53 confidence
# Location: [0.0, 0.0, 228.86799973249435, 299.0]
# Detected healthy with 0.74 confidence
# Location: [0.0, 0.0, 218.81257224082947, 299.0]
# Detected healthy with 0.91 confidence
# Location: [0.0, 0.0, 225.85478079319, 299.0]
# Detected healthy with 0.74 confidence
# Location: [0.0, 0.0, 235.55862003564835, 299.0]
# Detected healthy with 0.54 confidence
# Location: [12.729854226112366, 0.0, 299.0, 299.0]
# Detected healthy with 0.69 confidence
# Location: [58.6153821349144, 0.0, 299.0, 299.0]
# Detected healthy with 0.66 confidence
# Location: [69.48376834392548, 0.0, 299.0, 299.0]
# Detected healthy with 0.85 confidence
# Location: [0.0, 0.0, 192.13682967424393, 299.0]
# Detected healthy with 0.95 confidence
# Location: [0.0, 0.0, 199.97604644298553, 299.0]
# Detected healthy with 0.50 confidence
# Location: [0.0, 0.0, 219.50493091344833, 299.0]
# Detected healthy with 0.61 confidence
# Location: [0.0, 0.0, 215.27238082885742, 299.0]
# Detected healthy with 0.90 confidence
# Location: [0.0, 0.0, 223.49512249231339, 299.0]
# Detected healthy with 0.68 confidence
# Location: [0.0, 0.0, 231.24629962444305, 299.0]
# Detected healthy with 0.52 confidence
# Location: [0.0, 0.0, 208.66848134994507, 299.0]
# Detected healthy with 0.72 confidence
# Location: [0.0, 0.0, 222.10076355934143, 299.0]
# Detected healthy with 0.86 confidence
# Location: [85.80963182449341, 0.0, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [81.31549352407455, 0.0, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [98.16950571537018, 0.0, 299.0, 299.0]
# Detected healthy with 0.58 confidence
# Location: [0.0, 17.947414577007294, 198.09538435935974, 299.0]
# Detected healthy with 0.99 confidence
# Location: [81.0032023191452, 0.0, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [90.7887544631958, 0.0, 299.0, 299.0]
# Detected healthy with 0.82 confidence
# Location: [0.0, 22.825576782226562, 199.96428406238556, 299.0]
# Detected healthy with 0.68 confidence
# Location: [0.0, 25.3061380982399, 203.92535483837128, 299.0]
# Detected healthy with 0.64 confidence
# Location: [69.39916831254959, 0.0, 299.0, 299.0]
# Detected healthy with 0.65 confidence
# Location: [0.0, 39.887426674366, 190.28074383735657, 299.0]
# Detected healthy with 0.81 confidence
# Location: [0.0, 38.91161245107651, 192.11464154720306, 299.0]
# Detected healthy with 0.61 confidence
# Location: [0.0, 39.93313956260681, 195.91351622343063, 299.0]
# Detected healthy with 0.55 confidence
# Location: [0.0, 47.835641503334045, 274.79797518253326, 299.0]
# Detected healthy with 0.73 confidence
# Location: [0.0, 42.26239389181137, 193.26402217149734, 299.0]
# Detected healthy with 0.68 confidence
# Location: [0.0, 42.984087228775024, 200.25951981544495, 299.0]
# Detected healthy with 0.73 confidence
# Location: [0.0, 45.805169463157654, 269.01124036312103, 299.0]
# Detected healthy with 0.97 confidence
# Location: [0.0, 53.96884971857071, 268.595850110054, 299.0]
# Detected healthy with 0.97 confidence
# Location: [0.0, 51.00054168701172, 269.04378294944763, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 53.099360287189484, 273.3817845582962, 299.0]
# Detected healthy with 0.69 confidence
# Location: [0.0, 23.14740264415741, 299.0, 299.0]
# Detected healthy with 0.95 confidence
# Location: [0.0, 25.207726180553436, 299.0, 299.0]
# Detected healthy with 0.97 confidence
# Location: [0.0, 24.003917813301086, 299.0, 299.0]
# Detected healthy with 0.96 confidence
# Location: [0.0, 21.14888507127762, 299.0, 299.0]
# Detected healthy with 0.90 confidence
# Location: [0.0, 15.730776131153107, 299.0, 299.0]
# Detected healthy with 0.62 confidence
# Location: [0.0, 7.859818756580353, 299.0, 299.0]
# Detected healthy with 0.73 confidence
# Location: [0.0, 67.47553789615631, 217.8723659515381, 299.0]
# Detected healthy with 0.85 confidence
# Location: [0.0, 66.19479286670685, 230.27816659212112, 299.0]
# Detected healthy with 0.97 confidence
# Location: [0.0, 57.3726509809494, 268.82418286800385, 299.0]
# Detected healthy with 0.92 confidence
# Location: [0.0, 55.05458873510361, 281.6513440608978, 299.0]
# Detected healthy with 0.62 confidence
# Location: [0.0, 31.21739375591278, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 36.865635454654694, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 33.63046395778656, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 31.98494255542755, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 31.005956053733826, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 29.910824954509735, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 26.568615794181824, 299.0, 299.0]
# Detected healthy with 0.89 confidence
# Location: [1.6725926995277405, 20.543853163719177, 299.0, 299.0]
# Detected healthy with 0.70 confidence
# Location: [0.0, 71.28729772567749, 221.27828800678253, 299.0]
# Detected healthy with 0.72 confidence
# Location: [0.0, 69.57758224010468, 237.3850860595703, 299.0]
# Detected healthy with 0.52 confidence
# Location: [0.0, 61.78940707445145, 277.09185326099396, 299.0]
# Detected healthy with 0.94 confidence
# Location: [0.0, 42.18593841791153, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 41.37328267097473, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 38.90583819150925, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 37.73587340116501, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 37.5484060049057, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 37.45610696077347, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 36.95743548870087, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 35.03426843881607, 299.0, 299.0]
# Detected healthy with 0.94 confidence
# Location: [100.83503937721252, 69.90933483839035, 299.0, 299.0]
# Detected healthy with 0.93 confidence
# Location: [109.66254562139511, 75.39942598342896, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 49.52605599164963, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 46.390062749385834, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 44.23284214735031, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 43.64331519603729, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 43.47163790464401, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 43.78428554534912, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 45.5487317442894, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 46.90627086162567, 299.0, 299.0]
# Detected healthy with 0.60 confidence
# Location: [17.618584752082825, 47.03592437505722, 299.0, 299.0]
# Detected healthy with 0.97 confidence
# Location: [98.92267233133316, 73.27891826629639, 299.0, 299.0]
# Detected healthy with 0.98 confidence
# Location: [103.05201643705368, 75.69263005256653, 299.0, 299.0]
# Detected healthy with 0.70 confidence
# Location: [114.90494954586029, 72.80612403154373, 299.0, 299.0]
# Detected healthy with 0.77 confidence
# Location: [0.0, 52.53636997938156, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 54.47333109378815, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 51.30096358060837, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 49.97202843427658, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 49.75132340192795, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 49.67153525352478, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 50.58928608894348, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 53.73429715633392, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 57.62459760904312, 299.0, 299.0]
# Detected healthy with 0.62 confidence
# Location: [93.00143647193909, 78.797150015831, 299.0, 299.0]
# Detected healthy with 0.75 confidence
# Location: [92.07978266477585, 75.18659818172455, 299.0, 299.0]
# Detected healthy with 0.93 confidence
# Location: [0.0, 62.90424907207489, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 60.27166789770126, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 56.343210995197296, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 55.652064204216, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 55.74634146690369, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 56.347185254096985, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 58.64799600839615, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 61.533842623233795, 299.0, 299.0]
# Detected healthy with 0.96 confidence
# Location: [0.0, 66.43782860040665, 299.0, 299.0]
# Detected healthy with 0.96 confidence
# Location: [0.0, 73.3747638463974, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 68.58555018901825, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 65.40862029790878, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 64.89387357234955, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 65.55290549993515, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 66.7734307050705, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 67.93673014640808, 299.0, 299.0]
# Detected healthy with 0.98 confidence
# Location: [0.0, 67.72292214632034, 299.0, 299.0]
# Detected healthy with 0.84 confidence
# Location: [0.0, 77.09090977907181, 299.0, 299.0]
# Detected healthy with 0.98 confidence
# Location: [0.0, 77.58706837892532, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 76.1953114271164, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 76.15025794506073, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 76.0111945271492, 299.0, 299.0]
# Detected healthy with 0.98 confidence
# Location: [0.0, 75.45317649841309, 299.0, 299.0]
# Detected healthy with 0.96 confidence
# Location: [0.0, 73.48987478017807, 299.0, 299.0]
# Detected healthy with 0.50 confidence
# Location: [0.0, 69.25335043668747, 299.0, 299.0]
# Detected healthy with 0.52 confidence
# Location: [0.0, 106.76531088352203, 228.11046677827835, 299.0]
# Detected healthy with 0.53 confidence
# Location: [0.0, 109.17568999528885, 232.75462889671326, 299.0]
# Detected healthy with 0.80 confidence
# Location: [72.76415371894836, 114.82573169469833, 299.0, 299.0]
# Detected healthy with 0.81 confidence
# Location: [76.54750561714172, 116.49296003580093, 299.0, 299.0]
# Detected healthy with 0.64 confidence
# Location: [70.20182603597641, 101.31494450569153, 299.0, 299.0]
# Detected healthy with 0.59 confidence
# Location: [70.26493299007416, 100.87549483776093, 299.0, 299.0]
